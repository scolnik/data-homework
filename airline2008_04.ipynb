# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as sm

# %%
# US commercial flight data for 2008 from http://stat-computing.org/dataexpo/2009/the-data.html

# %%
location = '2008.csv'
df = pd.read_csv(location)
df.head(10)
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   2003.0        1955   2211.0
# 1  2008      1           3          4    754.0         735   1002.0
# 2  2008      1           3          4    628.0         620    804.0
# 3  2008      1           3          4    926.0         930   1054.0
# 4  2008      1           3          4   1829.0        1755   1959.0
# 5  2008      1           3          4   1940.0        1915   2121.0
# 6  2008      1           3          4   1937.0        1830   2037.0
# 7  2008      1           3          4   1039.0        1040   1132.0
# 8  2008      1           3          4    617.0         615    652.0
# 9  2008      1           3          4   1620.0        1620   1639.0
#
#    CRSArrTime UniqueCarrier  FlightNum        ...         TaxiIn  TaxiOut  \
# 0        2225            WN        335        ...            4.0      8.0
# ...

# %%
df.describe()
# Out:
#             Year         Month    DayofMonth     DayOfWeek       DepTime  \
# count  7009728.0  7.009728e+06  7.009728e+06  7.009728e+06  6.873482e+06
# mean      2008.0  6.375130e+00  1.572801e+01  3.924182e+00  1.333830e+03
# std          0.0  3.406737e+00  8.797068e+00  1.988259e+00  4.780689e+02
# min       2008.0  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%       2008.0  3.000000e+00  8.000000e+00  2.000000e+00  9.280000e+02
# 50%       2008.0  6.000000e+00  1.600000e+01  4.000000e+00  1.325000e+03
# 75%       2008.0  9.000000e+00  2.300000e+01  6.000000e+00  1.728000e+03
# max       2008.0  1.200000e+01  3.100000e+01  7.000000e+00  2.400000e+03
#
#          CRSDepTime       ArrTime    CRSArrTime     FlightNum  \
# count  7.009728e+06  6.858079e+06  7.009728e+06  7.009728e+06
# mean   1.326086e+03  1.481258e+03  1.494801e+03  2.224200e+03
# std    4.642509e+02  5.052251e+02  4.826728e+02  1.961716e+03
# ...

# %%
len(df)
# Out:
# 7009728

# %%
# df has 7,009,728 rows

# %%
# check for duplicate rows

# %%
dfdup = df[df.duplicated(keep = False)]
len(dfdup)
# Out:
# 8

# %%
dfdup
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 938220  2008      2          28          4    829.0         835   1341.0
# 938221  2008      2          28          4    829.0         835   1341.0
# 938222  2008      2          28          4   1427.0        1435   1640.0
# 938223  2008      2          28          4   1427.0        1435   1640.0
# 938224  2008      2          28          4   1854.0        1807   1946.0
# 938225  2008      2          28          4   1854.0        1807   1946.0
# 938226  2008      2          28          4   2027.0        1942   2314.0
# 938227  2008      2          28          4   2027.0        1942   2314.0
#
#         CRSArrTime UniqueCarrier  FlightNum        ...         TaxiIn  \
# 938220        1350            F9        728        ...            6.0
# 938221        1350            F9        728        ...            6.0
# 938222        1636            F9        727        ...            9.0
# ...

# %%
# 4 rows have been duplicated

# %%
# remove duplicate rows

# %%
df = df.drop_duplicates()
len(df)
# Out:
# 7009724

# %%
df.describe()
# Out:
#             Year         Month    DayofMonth     DayOfWeek       DepTime  \
# count  7009724.0  7.009724e+06  7.009724e+06  7.009724e+06  6.873478e+06
# mean      2008.0  6.375132e+00  1.572801e+01  3.924181e+00  1.333830e+03
# std          0.0  3.406736e+00  8.797066e+00  1.988260e+00  4.780689e+02
# min       2008.0  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%       2008.0  3.000000e+00  8.000000e+00  2.000000e+00  9.280000e+02
# 50%       2008.0  6.000000e+00  1.600000e+01  4.000000e+00  1.325000e+03
# 75%       2008.0  9.000000e+00  2.300000e+01  6.000000e+00  1.728000e+03
# max       2008.0  1.200000e+01  3.100000e+01  7.000000e+00  2.400000e+03
#
#          CRSDepTime       ArrTime    CRSArrTime     FlightNum  \
# count  7.009724e+06  6.858075e+06  7.009724e+06  7.009724e+06
# mean   1.326086e+03  1.481258e+03  1.494801e+03  2.224201e+03
# std    4.642509e+02  5.052251e+02  4.826728e+02  1.961716e+03
# ...

# %%
# df has 7,009,724 rows
# there were 7,009,724 total flights in 2008

# %%
df.to_csv('2008_r1.csv',index=False)

# %%
dfc = df[df['Cancelled'] == 1]
dfc.head()
# Out:
#      Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 178  2008      1           3          4      NaN         700      NaN
# 373  2008      1           3          4      NaN        1100      NaN
# 399  2008      1           3          4      NaN         905      NaN
# 401  2008      1           3          4      NaN        1620      NaN
# 415  2008      1           3          4      NaN        1930      NaN
#
#      CRSArrTime UniqueCarrier  FlightNum        ...         TaxiIn  TaxiOut  \
# 178         830            WN        126        ...            NaN      NaN
# 373        1215            WN       1146        ...            NaN      NaN
# 399        1025            WN        469        ...            NaN      NaN
# 401        1740            WN        618        ...            NaN      NaN
# 415        2035            WN       2528        ...            NaN      NaN
#
#      Cancelled  CancellationCode  Diverted  CarrierDelay WeatherDelay  \
# ...

# %%
len(dfc)
# Out:
# 137434

# %%
# 137,434 flights were cancelled in 2008

# %%
# reason for cancellation (A = carrier, B = weather, C = NAS, D = security)

# %%
len(df[df['CancellationCode'] == 'A'])
# Out:
# 54330

# %%
# 54,330 cancelled due to carrier

# %%
dfcA = df[(df['Cancelled'] == 1) & (df['CancellationCode'] == 'A')]
dfcA.describe()
# Out:
#           Year         Month    DayofMonth     DayOfWeek      DepTime  \
# count  54330.0  54330.000000  54330.000000  54330.000000   574.000000
# mean    2008.0      5.564550     15.031235      3.733462  1247.494774
# std        0.0      3.463113      8.693932      1.915551   513.326532
# min     2008.0      1.000000      1.000000      1.000000     7.000000
# 25%     2008.0      3.000000      8.000000      2.000000   813.000000
# 50%     2008.0      5.000000     14.000000      4.000000  1207.000000
# 75%     2008.0      8.000000     23.000000      5.000000  1628.000000
# max     2008.0     12.000000     31.000000      7.000000  2349.000000
#
#          CRSDepTime  ArrTime    CRSArrTime     FlightNum  ActualElapsedTime  \
# count  54330.000000      0.0  54330.000000  54330.000000                0.0
# mean    1303.008448      NaN   1466.187686   2402.202945                NaN
# std      461.645574      NaN    478.624993   2117.814574                NaN
# ...

# %%
dfcA = df[df['CancellationCode'] == 'A']
dfcA.describe()
# Out:
#           Year         Month    DayofMonth     DayOfWeek      DepTime  \
# count  54330.0  54330.000000  54330.000000  54330.000000   574.000000
# mean    2008.0      5.564550     15.031235      3.733462  1247.494774
# std        0.0      3.463113      8.693932      1.915551   513.326532
# min     2008.0      1.000000      1.000000      1.000000     7.000000
# 25%     2008.0      3.000000      8.000000      2.000000   813.000000
# 50%     2008.0      5.000000     14.000000      4.000000  1207.000000
# 75%     2008.0      8.000000     23.000000      5.000000  1628.000000
# max     2008.0     12.000000     31.000000      7.000000  2349.000000
#
#          CRSDepTime  ArrTime    CRSArrTime     FlightNum  ActualElapsedTime  \
# count  54330.000000      0.0  54330.000000  54330.000000                0.0
# mean    1303.008448      NaN   1466.187686   2402.202945                NaN
# std      461.645574      NaN    478.624993   2117.814574                NaN
# ...

# %%
# there are no flights with CancellationCode = 'A' that do not also have Cancelled = 1

# %%
len(df[df['CancellationCode'] == 'B'])
# Out:
# 54904

# %%
# 54,904 cancelled due to weather

# %%
len(df[df['CancellationCode'] == 'C'])
# Out:
# 28188

# %%
# 28,188 cancelled due to NAS (National Air System)

# %%
len(df[df['CancellationCode'] == 'D'])
# Out:
# 12

# %%
# 12 cancelled due to security

# %%
# Summary of cancelled flights
# 137,434 flights were cancelled with the following reasons:
# carrier: 54,330, weather: 54,904, NAS (National Air System): 28,188, security: 12

# %%
dfd = df[(df['CarrierDelay'] + df['WeatherDelay'] + df['NASDelay'] + df['SecurityDelay'] + df['LateAircraftDelay']) > 0]
dfd.head()
# Out:
#     Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 4   2008      1           3          4   1829.0        1755   1959.0
# 6   2008      1           3          4   1937.0        1830   2037.0
# 11  2008      1           3          4   1644.0        1510   1845.0
# 16  2008      1           3          4   1452.0        1425   1640.0
# 18  2008      1           3          4   1323.0        1255   1526.0
#
#     CRSArrTime UniqueCarrier  FlightNum        ...         TaxiIn  TaxiOut  \
# 4         1925            WN       3920        ...            3.0     10.0
# 6         1940            WN        509        ...            3.0      7.0
# 11        1725            WN       1333        ...            6.0      8.0
# 16        1625            WN        675        ...            7.0      8.0
# 18        1510            WN          4        ...            4.0      9.0
#
#     Cancelled  CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
dfd.describe()
# Out:
#             Year         Month    DayofMonth     DayOfWeek       DepTime  \
# count  1524733.0  1.524733e+06  1.524733e+06  1.524733e+06  1.524733e+06
# mean      2008.0  6.068517e+00  1.570049e+01  3.963915e+00  1.501993e+03
# std          0.0  3.511026e+00  8.781586e+00  1.984438e+00  4.721422e+02
# min       2008.0  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%       2008.0  3.000000e+00  8.000000e+00  2.000000e+00  1.140000e+03
# 50%       2008.0  6.000000e+00  1.600000e+01  4.000000e+00  1.541000e+03
# 75%       2008.0  9.000000e+00  2.300000e+01  6.000000e+00  1.902000e+03
# max       2008.0  1.200000e+01  3.100000e+01  7.000000e+00  2.400000e+03
#
#          CRSDepTime       ArrTime    CRSArrTime     FlightNum  \
# count  1.524733e+06  1.524733e+06  1.524733e+06  1.524733e+06
# mean   1.444966e+03  1.589677e+03  1.615356e+03  2.240762e+03
# std    4.388771e+02  5.713560e+02  4.710017e+02  1.990780e+03
# ...

# %%
# all values for dfd['Cancelled'] are 0, therefore there are no flights with data indicating both delays and cancelled

# %%
len(dfd)
# Out:
# 1524733

# %%
# 1,524,733 flights were delayed in 2008

# %%
len(df[df['CarrierDelay'] > 0])
# Out:
# 670620

# %%
# 670,620 flights were delayed due to carrier delay

# %%
len(df[df['WeatherDelay'] > 0])
# Out:
# 99985

# %%
# 99,985 flights were delayed due to weather

# %%
len(df[df['NASDelay'] > 0])
# Out:
# 928030

# %%
# 928,030 flights were delayed due to NAS

# %%
len(df[df['SecurityDelay'] > 0])
# Out:
# 6202

# %%
# 6,202 flights were delayed due to security

# %%
len(df[df['LateAircraftDelay'] > 0])
# Out:
# 699418

# %%
# 699,418 flights were delayed due to late aircraft

# %%
# 1,524,733 flights were delayed: 
# 670,620 carrier delays
# 99,985 weather delays
# 928,030 NAS (National Air System) delays
# 6,202 security delays
# 699,418 late aircraft delays
# These add up to more than 1,524,733 because some flights have multiple delays, such as carrier delay and late aircraft delay.

# %%
dfd['TotalDelay'] = dfd['CarrierDelay'] + dfd['WeatherDelay'] + dfd['NASDelay'] + dfd['SecurityDelay'] + dfd['LateAircraftDelay']
dfd.head()
# Out:
# C:\Users\Sarah\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#     Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 4   2008      1           3          4   1829.0        1755   1959.0
# 6   2008      1           3          4   1937.0        1830   2037.0
# 11  2008      1           3          4   1644.0        1510   1845.0
# 16  2008      1           3          4   1452.0        1425   1640.0
# 18  2008      1           3          4   1323.0        1255   1526.0
#
#     CRSArrTime UniqueCarrier  FlightNum     ...     TaxiOut  Cancelled  \
# 4         1925            WN       3920     ...        10.0          0
# ...

# %%
dfd.describe()
# Out:
#             Year         Month    DayofMonth     DayOfWeek       DepTime  \
# count  1524733.0  1.524733e+06  1.524733e+06  1.524733e+06  1.524733e+06
# mean      2008.0  6.068517e+00  1.570049e+01  3.963915e+00  1.501993e+03
# std          0.0  3.511026e+00  8.781586e+00  1.984438e+00  4.721422e+02
# min       2008.0  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%       2008.0  3.000000e+00  8.000000e+00  2.000000e+00  1.140000e+03
# 50%       2008.0  6.000000e+00  1.600000e+01  4.000000e+00  1.541000e+03
# 75%       2008.0  9.000000e+00  2.300000e+01  6.000000e+00  1.902000e+03
# max       2008.0  1.200000e+01  3.100000e+01  7.000000e+00  2.400000e+03
#
#          CRSDepTime       ArrTime    CRSArrTime     FlightNum  \
# count  1.524733e+06  1.524733e+06  1.524733e+06  1.524733e+06
# mean   1.444966e+03  1.589677e+03  1.615356e+03  2.240762e+03
# std    4.388771e+02  5.713560e+02  4.710017e+02  1.990780e+03
# ...

# %%
print('Total delay mean:',dfd['TotalDelay'].mean())
print('Total delay median:',dfd['TotalDelay'].median())
print('Total delay sum:',dfd['TotalDelay'].sum())
# Out:
# Total delay mean: 56.82168878092099
# Total delay median: 37.0
# Total delay sum: 86637904.0

# %%
# for flights that were delayed:
# mean delay: approx. 56.8 minutes
# median delay: 37 minutes
# the total number of minutes of delays over all flights was 86,637,904 minutes

# %%
dfcd = dfd[dfd['CarrierDelay'] > 0]
dfcd.describe()
# Out:
#            Year          Month     DayofMonth      DayOfWeek        DepTime  \
# count  670620.0  670620.000000  670620.000000  670620.000000  670620.000000
# mean     2008.0       6.089744      15.741817       4.033481    1512.881065
# std         0.0       3.524034       8.766271       1.994072     473.642788
# min      2008.0       1.000000       1.000000       1.000000       1.000000
# 25%      2008.0       3.000000       8.000000       2.000000    1144.000000
# 50%      2008.0       6.000000      16.000000       4.000000    1543.000000
# 75%      2008.0       9.000000      23.000000       6.000000    1912.000000
# max      2008.0      12.000000      31.000000       7.000000    2400.000000
#
#           CRSDepTime        ArrTime     CRSArrTime      FlightNum  \
# count  670620.000000  670620.000000  670620.000000  670620.000000
# mean     1449.318537    1574.368326    1609.602225    2197.267962
# std       446.871757     583.367552     484.744220    1942.333879
# ...

# %%
# 670,620 flights had carrier delays
# some of the flights with carrier delays also had other types of delays (max values for other delays are > 0)

# %%
print('Total carrier delay mean:',dfcd['CarrierDelay'].mean())
print('Total carrier delay median:',dfcd['CarrierDelay'].median())
print('Total carrier delay sum:',dfcd['CarrierDelay'].sum())
# Out:
# Total carrier delay mean: 35.85961050967761
# Total carrier delay median: 19.0
# Total carrier delay sum: 24048172.0

# %%
# for flights with carrier delays:
# mean carrier delay: approx. 35.9 minutes
# median carrier delay: 19 minutes
# the total number of minutes of carrier delays over all flights was 24,048,172 minutes

# %%
dfwd = dfd[dfd['WeatherDelay'] > 0]
dfwd.describe()
# Out:
#           Year         Month    DayofMonth     DayOfWeek       DepTime  \
# count  99985.0  99985.000000  99985.000000  99985.000000  99985.000000
# mean    2008.0      6.200670     15.993139      3.976817   1562.130810
# std        0.0      3.686919      8.730557      1.970509    484.679211
# min     2008.0      1.000000      1.000000      1.000000      1.000000
# 25%     2008.0      3.000000      8.000000      2.000000   1220.000000
# 50%     2008.0      6.000000     16.000000      4.000000   1635.000000
# 75%     2008.0      9.000000     23.000000      6.000000   1940.000000
# max     2008.0     12.000000     31.000000      7.000000   2400.000000
#
#          CRSDepTime       ArrTime    CRSArrTime     FlightNum  \
# count  99985.000000  99985.000000  99985.000000  99985.000000
# mean    1480.988678   1573.624964   1655.398900   2736.081712
# std      434.954475    638.547562    466.131013   2006.603338
# min        5.000000      1.000000      1.000000      1.000000
# ...

# %%
len(dfwd)
# Out:
# 99985

# %%
# 99,985 flights had weather delays

# %%
print('Total weather delay mean:',dfwd['WeatherDelay'].mean())
print('Total weather delay median:',dfwd['WeatherDelay'].median())
print('Total weather delay sum:',dfwd['WeatherDelay'].sum())
# Out:
# Total weather delay mean: 46.34412161824274
# Total weather delay median: 25.0
# Total weather delay sum: 4633717.0

# %%
# for flights with weather delays:
# mean weather delay: approx. 46.3 minutes
# median weather delay: 25 minutes
# the total number of minutes of weather delays over all flights was 4,633,717 minutes

# %%
dfnd = dfd[dfd['NASDelay'] > 0]
dfnd.describe()
# Out:
#            Year          Month     DayofMonth      DayOfWeek        DepTime  \
# count  928030.0  928030.000000  928030.000000  928030.000000  928030.000000
# mean     2008.0       6.121680      15.667347       3.938570    1449.742551
# std         0.0       3.509688       8.768080       1.968808     465.204916
# min      2008.0       1.000000       1.000000       1.000000       1.000000
# 25%      2008.0       3.000000       8.000000       2.000000    1101.000000
# 50%      2008.0       6.000000      16.000000       4.000000    1504.000000
# 75%      2008.0       9.000000      23.000000       5.000000    1829.000000
# max      2008.0      12.000000      31.000000       7.000000    2400.000000
#
#           CRSDepTime        ArrTime     CRSArrTime      FlightNum  \
# count  928030.000000  928030.000000  928030.000000  928030.000000
# mean     1399.940372    1581.096720    1584.961590    2114.987260
# std       439.919845     546.835226     462.344504    1913.163405
# ...

# %%
len(dfnd)
# Out:
# 928030

# %%
# 928,030 flights had NAS delays (National Air System Delays)

# %%
print('Total NAS delay mean:',dfnd['NASDelay'].mean())
print('Total NAS delay median:',dfnd['NASDelay'].median())
print('Total NAS delay sum:',dfnd['NASDelay'].sum())
# Out:
# Total NAS delay mean: 28.201089404437358
# Total NAS delay median: 18.0
# Total NAS delay sum: 26171457.0

# %%
# for flights with NAS delays:
# mean NAS delay: approx. 28.2 minutes
# median NAS delay: 18 minutes
# the total number of minutes of NAS delays over all flights was 26,171,457 minutes

# %%
dfsd = dfd[dfd['SecurityDelay'] > 0]
dfsd.describe()
# Out:
#          Year        Month   DayofMonth    DayOfWeek      DepTime  \
# count  6202.0  6202.000000  6202.000000  6202.000000  6202.000000
# mean   2008.0     5.721058    15.315060     4.152854  1409.861013
# std       0.0     3.601220     9.037009     1.997462   501.733070
# min    2008.0     1.000000     1.000000     1.000000     2.000000
# 25%    2008.0     3.000000     7.000000     2.000000   952.000000
# 50%    2008.0     5.000000    16.000000     4.000000  1449.000000
# 75%    2008.0     8.000000    23.000000     6.000000  1841.000000
# max    2008.0    12.000000    31.000000     7.000000  2359.000000
#
#         CRSDepTime      ArrTime   CRSArrTime    FlightNum  ActualElapsedTime  \
# count  6202.000000  6202.000000  6202.000000  6202.000000        6202.000000
# mean   1363.131087  1543.808933  1540.470332  1928.644953         142.135601
# std     485.476743   563.897545   520.185012  1726.675741          78.194122
# ...

# %%
len(dfsd)
# Out:
# 6202

# %%
# 6,202 flights had security delays

# %%
print('Total security delay mean:',dfsd['SecurityDelay'].mean())
print('Total security delay median:',dfsd['SecurityDelay'].median())
print('Total security delay sum:',dfsd['SecurityDelay'].sum())
# Out:
# Total security delay mean: 18.432118671396324
# Total security delay median: 13.0
# Total security delay sum: 114316.0

# %%
# for flights with security delays:
# mean security delay: approx. 18.4 minutes
# median security delay: 13 minutes
# the total number of minutes of security delays over all flights was 114,316 minutes

# %%
dfld = dfd[dfd['LateAircraftDelay'] > 0]
dfld.describe()
# Out:
#            Year          Month     DayofMonth      DayOfWeek        DepTime  \
# count  699418.0  699418.000000  699418.000000  699418.000000  699418.000000
# mean     2008.0       6.032784      15.756703       3.974422    1635.968214
# std         0.0       3.566436       8.793711       1.983934     421.034503
# min      2008.0       1.000000       1.000000       1.000000       1.000000
# 25%      2008.0       3.000000       8.000000       2.000000    1344.000000
# 50%      2008.0       6.000000      16.000000       4.000000    1706.000000
# 75%      2008.0       9.000000      23.000000       5.000000    1948.000000
# max      2008.0      12.000000      31.000000       7.000000    2400.000000
#
#           CRSDepTime       ArrTime     CRSArrTime      FlightNum  \
# count  699418.000000  699418.00000  699418.000000  699418.000000
# mean     1568.183011    1661.14819    1722.167850    2037.425372
# std       371.619187     597.20583     434.690595    1833.540916
# ...

# %%
len(dfld)
# Out:
# 699418

# %%
# 699,418 flights had late aircraft delays

# %%
print('Total late aircraft delay mean:',dfld['LateAircraftDelay'].mean())
print('Total late aircraft delay median:',dfld['LateAircraftDelay'].median())
print('Total late aircraft delay sum:',dfld['LateAircraftDelay'].sum())
# Out:
# Total late aircraft delay mean: 45.28085065011195
# Total late aircraft delay median: 29.0
# Total late aircraft delay sum: 31670242.0

# %%
# for flights with late aircraft delays:
# mean late aircraft delay: approx. 45.3 minutes
# median late aircraft delay: 29 minutes
# the total number of minutes of late aircraft delays over all flights was 31,670,242 minutes

# %%
# the total number of minutes of delays over all flights was 86,637,904 minutes
# carrier delays: 24,048,172 minutes
# weather delays: 4,633,717 minutes
# NAS delays: 26,171,457 minutes
# security delays: 114,316 minutes
# late aircraft delays: 31,670,242 minutes
